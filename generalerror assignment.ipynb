# %%
#Q1. Explain why we have to use the Exception class while creating a Custom Exception.


'''there are different errors due to arthematic and logic operations.like Zero division error, out of rangr for list i.e is Index error etc
  indidual error class is used to handle a purticular error.Exception class is a super class which contains all error and can be used when we are nit aware of 
 type of possible error in code. using this error code can be skipped and further excutation is possible.'''
# Out:
# 'there are different errors due to arthematic and logic operations.like Zero division error, out of rangr for list i.e is Index error etc\n  indidual error class is used to handle a purticular error.Exception class is a super class which contains all error and can be used when we are nit aware of \n type of possible error in code. using this error code can be skipped and further excutation is possible.'

# %%
# Q2# print Python exception hierarchy
exceptions = [BaseException]
while exceptions:
    exception = exceptions.pop(0)
    print(exception.__name__)
    exceptions.extend(exception.__subclasses__())
# Out:
# BaseException
# Exception
# GeneratorExit
# SystemExit
# KeyboardInterrupt
# CancelledError
# AbortThread
# TypeError
# StopAsyncIteration
# StopIteration
# ImportError
# OSError
# EOFError
# RuntimeError
# NameError
# AttributeError
# SyntaxError
# LookupError
# ValueError
# AssertionError
# ArithmeticError
# SystemError
# ReferenceError
# MemoryError
# BufferError
# Warning
# _OptionError
# _Error
# error
# Verbose
# Error
# SubprocessError
# TokenError
# StopTokenizing
# ClassFoundException
# EndOfBlock
# TraitError
# Error
# Error
# _GiveupOnSendfile
# error
# Incomplete
# TimeoutError
# InvalidStateError
# LimitOverrunError
# QueueEmpty
# QueueFull
# Empty
# Full
# ArgumentError
# ZMQBaseError
# PickleError
# _Stop
# ArgumentError
# ArgumentTypeError
# ConfigError
# ConfigurableError
# ApplicationError
# error
# TimeoutError
# error
# ReturnValueIgnoredError
# KeyReuseError
# UnknownKeyError
# LeakedCallbackError
# BadYieldError
# ReturnValueIgnoredError
# Return
# ...

# %%
 #Q3. What errors are defined in the ArithmeticError class? Explain any two with an example.
    
    
'''Errors like " Zerodivision error" , "overflow error" are arthematic error.
    zerodivision error:'''
        
a=10
a/0
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[6], line 8
#       4 '''Errors like " Zerodivision error" , "overflow error" are arthematic error.
#       5    zerodivision error:'''
#       7 a=10
# ----> 8 a/0
#      10 #overflow error is duve to lage calculations:
#      12 b=1000
#
# ZeroDivisionError: division by zero

# %%
#overflow error is duve to lage calculations:

b=1000
b**100000  #ValueError: Exceeds the limit (4300) for integer string conversion; use sys.set_int_max_str_digits()
           #to increase the limit
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File /opt/conda/lib/python3.10/site-packages/IPython/core/formatters.py:706, in PlainTextFormatter.__call__(self, obj)
#     699 stream = StringIO()
#     700 printer = pretty.RepresentationPrinter(stream, self.verbose,
#     701     self.max_width, self.newline,
#     702     max_seq_length=self.max_seq_length,
#     703     singleton_pprinters=self.singleton_printers,
#     704     type_pprinters=self.type_printers,
#     705     deferred_pprinters=self.deferred_printers)
# --> 706 printer.pretty(obj)
#     707 printer.flush()
#     708 return stream.getvalue()
#
# File /opt/conda/lib/python3.10/site-packages/IPython/lib/pretty.py:393, in RepresentationPrinter.pretty(self, obj)
#     390 for cls in _get_mro(obj_class):
#     391     if cls in self.type_pprinters:
#     392         # printer registered in self.type_pprinters
# ...

# %%
#Q4. Why LookupError class is used? Explain with an example KeyError and IndexError.

'''The LookupError class is a built-in Python exception class that serves as the base class for all errors that occur
when a key or index is not found'''


try:
    dict1={"ani":"student","key":"value"}
    dict1["ami"]
except KeyError as q:
          print("this is my keyerror",q)
        
try:
    l=[1,3,3,4]
    l[56]
except IndexError as z:
    print("this is my index error\n",z)
# Out:
# this is my keyerror 'ami'
# this is my index error
#  list index out of range

# %%
#Q5. Explain ImportError. What is ModuleNotFoundError?

'''import error is is exception class that works when an importing of any module,function is not possible overall i.e any error regarding import.
whereas Modulenotfound error is subclass of import error which handles only error regarding importing of module.'''
# Out:
# 'import error is is exception class that works when an importing of any module,function is not possible overall i.e any error regarding import.\nwhereas Modulenotfound error is subclass of import error which handles only error regarding importing of module.'

# %%
#Q6. List down some best practices for exception handling in python.

# %%
# use always specific exception not super case
try:
    10/0
except ZeroDivisionError as a:
    print(a)
    
    
    
# print always a valid msg
try:
    10/0
except ZeroDivisionError as a:
    print(a,"this is the Zero Error ")
    
# alwys try to logg.

import logging
logging.basicConfig(filename="error.log",level=logging.ERROR)
try:
    10/0
except ZeroDivisionError as e:
    logging.error("this is zero dev error,,,{}".format(e))
# Out:
# division by zero
# division by zero this is the Zero Error
